# %%
'''
@Author:Sailesh Chauhan
@Date:2021-06-22
@Last Modified by:Sailesh Chauhan
@Last Modified time:2021-06-22
@Title:Write a program to draw swarm plot of “total bill” against day for a dataset given in url.
'''

# %%
'''
https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv
'''

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_df=pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=plt.figure(figsize=(8,6),dpi=100)
sns.swarmplot(x='day',y='total_bill',data=tips_df,size=5)
plt.show()
