# %%
'''
@Author:Sailesh Chauhan
@Date:2021-06-18
@Last Modified by:Sailesh Chauhan
@Last Modified time:2021-06-18
@Title:Write a Python program to plot several lines with different format styles in one command
using arrays.
'''

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
growth=np.arange(1,10,1)
plt.plot(growth,growth,'rs',growth,np.log(growth),'bo',growth,growth**2,'gD')
plt.show()
